-- %%
select * from adjuster_dim
-- Out:
-- StatementMeta(, 4c9673e7-02bd-4e6c-97da-0171f3221dd6, 2, Finished, Available, Finished, False)
-- <Spark SQL result set with 8 rows and 4 fields>

-- %%
update adjuster_dim
set Experience_Years = 15
where Adjuster_ID = 101
-- Out:
-- StatementMeta(, 40db99aa-dcf9-457a-b6e6-77a5076d1267, 2, Finished, Available, Finished, False)
-- <Spark SQL result set with 1 rows and 1 fields>

-- %%
select * from adjuster_dim
-- Out:
-- StatementMeta(, 40db99aa-dcf9-457a-b6e6-77a5076d1267, 3, Finished, Available, Finished, False)
-- <Spark SQL result set with 8 rows and 4 fields>

-- %%
delete from adjuster_dim
where Adjuster_ID=109
-- Out:
-- StatementMeta(, d12f2a3f-1019-4822-bce9-c70c9705db87, 2, Finished, Available, Finished, False)
-- <Spark SQL result set with 1 rows and 1 fields>
